# %% [markdown]
# # Sentiment Analysis
#
#
# ### Zero Shot Labeling
#
# ### Code performed in Google Colab
#
# In this notebook I will use one of the hugging face models - Zero Shot model to label my tweets by sentiment. This approach allows me to assign sentiment labels to the tweets without explicitly training a sentiment analysis model.
#
# The Zero Shot model is a powerful language model that can generalize across various tasks, including sentiment analysis. It can assign sentiment labels such as positive, negative, or neutral to text inputs by leveraging its understanding of the underlying language patterns and contextual information.
#
# To perform the sentiment labeling, I am using Google Colab, a cloud-based Jupyter notebook environment provided by Google. Colab offers the advantage of running code on powerful remote servers, providing access to GPUs and TPUs for efficient deep learning computations.
#
# In the notebook, I will demonstrate how to load the Zero Shot model from the Hugging Face library, process the tweet data, and apply the model to predict sentiment labels for each tweet. The model's predictions will provide insights into the sentiment expressed in the tweets, enabling further analysis and interpretation of the collected data.
#
# By leveraging the Zero Shot model for sentiment labeling, I can efficiently categorize the tweets based on their sentiment without the need for extensive manual annotation or building a dedicated sentiment analysis model from scratch.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install transformers flair
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 58.2 MB/s eta 0:00:00
# Collecting flair
#   Downloading flair-0.12.2-py3-none-any.whl (373 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 373.1/373.1 kB 39.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from transformers) (23.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.9/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.9/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from transformers) (2.27.1)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 68.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from transformers) (3.11.0)
# Collecting huggingface-hub<1.0,>=0.11.0
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 29.6 MB/s eta 0:00:00
# Collecting gdown==4.4.0
#   Downloading gdown-4.4.0.tar.gz (14 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 73.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting sqlitedict>=1.6.0
#   Downloading sqlitedict-2.1.0.tar.gz (21 kB)
#   Preparing metadata (setup.py) ... done
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 7.5 MB/s eta 0:00:00
# Requirement already satisfied: gensim>=3.8.0 in /usr/local/lib/python3.9/dist-packages (from flair) (4.3.1)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.9/dist-packages (from flair) (1.2.2)
# Collecting pytorch-revgrad
#   Downloading pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting bpemb>=0.3.2
#   Downloading bpemb-0.3.4-py3-none-any.whl (19 kB)
# Collecting deprecated>=1.2.4
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting conllu>=4.0
#   Downloading conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting boto3
#   Downloading boto3-1.26.120-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 11.0 MB/s eta 0:00:00
# Collecting transformer-smaller-training-vocab>=0.2.1
#   Downloading transformer_smaller_training_vocab-0.2.3-py3-none-any.whl (12 kB)
# Requirement already satisfied: hyperopt>=0.2.7 in /usr/local/lib/python3.9/dist-packages (from flair) (0.2.7)
# Requirement already satisfied: matplotlib>=2.2.3 in /usr/local/lib/python3.9/dist-packages (from flair) (3.7.1)
# Collecting pptree
#   Downloading pptree-3.1.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Collecting segtok>=1.5.7
#   Downloading segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting wikipedia-api
#   Downloading Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Requirement already satisfied: torch!=1.8,>=1.5.0 in /usr/local/lib/python3.9/dist-packages (from flair) (2.0.0+cu118)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.9/dist-packages (from flair) (0.8.10)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.9/dist-packages (from flair) (9.1.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.9/dist-packages (from flair) (4.9.2)
# Collecting mpld3==0.3
#   Downloading mpld3-0.3.tar.gz (788 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 788.5/788.5 kB 70.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting janome
#   Downloading Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.7/19.7 MB 82.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.9/dist-packages (from flair) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from gdown==4.4.0->flair) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.9/dist-packages (from gdown==4.4.0->flair) (4.11.2)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 77.1 MB/s eta 0:00:00
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.9/dist-packages (from deprecated>=1.2.4->flair) (1.14.1)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.9/dist-packages (from gensim>=3.8.0->flair) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.9/dist-packages (from gensim>=3.8.0->flair) (6.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (4.5.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.9/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: py4j in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair) (0.10.9.7)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair) (3.1)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair) (2.2.1)
# Requirement already satisfied: future in /usr/local/lib/python3.9/dist-packages (from hyperopt>=0.2.7->flair) (0.18.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2.3->flair) (0.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2.3->flair) (1.0.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2.3->flair) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2.3->flair) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2.3->flair) (5.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2.3->flair) (4.39.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib>=2.2.3->flair) (8.4.0)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->flair) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.21.3->flair) (3.1.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.5.0->flair) (2.0.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.5.0->flair) (1.11.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch!=1.8,>=1.5.0->flair) (3.1.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch!=1.8,>=1.5.0->flair) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch!=1.8,>=1.5.0->flair) (3.25.2)
# Collecting datasets<3.0.0,>=2.0.0
#   Downloading datasets-2.11.0-py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 48.5 MB/s eta 0:00:00
# Collecting protobuf<=3.20.2
#   Downloading protobuf-3.20.2-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 77.0 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.120
#   Downloading botocore-1.29.120-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 111.1 MB/s eta 0:00:00
# Collecting s3transfer<0.7.0,>=0.6.0
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /packages/5e/c6/af903b5fab3f9b5b1e883f49a770066314c6dcceb589cf938d48c89556c1/s3transfer-0.6.0-py3-none-any.whl
#   Downloading s3transfer-0.6.0-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.6/79.6 kB 3.6 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.9/dist-packages (from ftfy->flair) (0.2.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (3.4)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting dill<0.3.7,>=0.3.0
#   Downloading dill-0.3.6-py3-none-any.whl (110 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 11.6 MB/s eta 0:00:00
# Collecting multiprocess
#   Downloading multiprocess-0.70.14-py39-none-any.whl (132 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 19.3 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 36.4 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.9/dist-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (9.0.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (from datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (1.5.3)
# Collecting xxhash
#   Downloading xxhash-3.2.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 25.5 MB/s eta 0:00:00
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib>=2.2.3->flair) (3.15.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.9/dist-packages (from beautifulsoup4->gdown==4.4.0->flair) (2.4.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch!=1.8,>=1.5.0->flair) (2.1.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.9/dist-packages (from requests->transformers) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch!=1.8,>=1.5.0->flair) (1.3.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (269 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 269.4/269.4 kB 29.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/dist-packages (from aiohttp->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (23.1.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 7.4 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 18.5 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas->datasets<3.0.0,>=2.0.0->transformer-smaller-training-vocab>=0.2.1->flair) (2022.7.1)
# Building wheels for collected packages: gdown, mpld3, sqlitedict, langdetect, pptree
#   Building wheel for gdown (pyproject.toml) ... done
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14776 sha256=d9ae9f16b7037123ed923b90d7d52e29c8b4e6333489ac08da0adbf9c39c850d
#   Stored in directory: /root/.cache/pip/wheels/7d/37/b6/b2a79c75e898c0b8e46ff255102602d7159a10d9af0d80641a
#   Building wheel for mpld3 (setup.py) ... done
#   Created wheel for mpld3: filename=mpld3-0.3-py3-none-any.whl size=116702 sha256=25791e175137adfbade916fd1885dbd2abafef297da114e88f79e31cc235810e
#   Stored in directory: /root/.cache/pip/wheels/a6/f4/e6/e40ff9021f6b3854af70fa8ea004f5ab95672817462df08fed
#   Building wheel for sqlitedict (setup.py) ... done
#   Created wheel for sqlitedict: filename=sqlitedict-2.1.0-py3-none-any.whl size=16863 sha256=a0cdb350e2bab3331dfb3d49e00ef145e18eb9125bd636f9a66de8a0efcf05aa
#   Stored in directory: /root/.cache/pip/wheels/f6/48/c4/942f7a1d556fddd2348cb9ac262f251873dfd8a39afec5678e
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993243 sha256=b3afdc77c68ca48c5ed34b7e47db1b5171c3f4ed01a183f49d887cdd1ecc17a5
#   Stored in directory: /root/.cache/pip/wheels/d1/c1/d9/7e068de779d863bc8f8fc9467d85e25cfe47fa5051fff1a1bb
#   Building wheel for pptree (setup.py) ... done
#   Created wheel for pptree: filename=pptree-3.1-py3-none-any.whl size=4629 sha256=d44b4d7220ef3069d0943e2095094147cffba933054b3fc4439588bca16b2912
#   Stored in directory: /root/.cache/pip/wheels/52/0e/51/514e690004ea9713bc3fdb678d5e2768fcc597d0c3b6a3abd2
# Successfully built gdown mpld3 sqlitedict langdetect pptree
# Installing collected packages: tokenizers, sqlitedict, sentencepiece, pptree, mpld3, janome, xxhash, segtok, protobuf, multidict, langdetect, jmespath, ftfy, frozenlist, dill, deprecated, conllu, async-timeout, yarl, wikipedia-api, responses, multiprocess, huggingface-hub, botocore, aiosignal, transformers, s3transfer, gdown, bpemb, aiohttp, boto3, datasets, transformer-smaller-training-vocab, pytorch-revgrad, flair
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.6.6
#     Uninstalling gdown-4.6.6:
#       Successfully uninstalled gdown-4.6.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.20.2 which is incompatible.
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 boto3-1.26.120 botocore-1.29.120 bpemb-0.3.4 conllu-4.5.2 datasets-2.11.0 deprecated-1.2.13 dill-0.3.6 flair-0.12.2 frozenlist-1.3.3 ftfy-6.1.1 gdown-4.4.0 huggingface-hub-0.14.1 janome-0.4.2 jmespath-1.0.1 langdetect-1.0.9 mpld3-0.3 multidict-6.0.4 multiprocess-0.70.14 pptree-3.1 protobuf-3.20.2 pytorch-revgrad-0.2.0 responses-0.18.0 s3transfer-0.6.0 segtok-1.5.11 sentencepiece-0.1.98 sqlitedict-2.1.0 tokenizers-0.13.3 transformer-smaller-training-vocab-0.2.3 transformers-4.28.1 wikipedia-api-0.5.8 xxhash-3.2.0 yarl-1.9.2

# %%
import pandas as pd
# Hugging Face model
from transformers import pipeline

# Import flair pre-trained sentiment model
from flair.models import TextClassifier
classifier = TextClassifier.load('en-sentiment')

# Import flair Sentence to process input text
from flair.data import Sentence

# Import accuracy_score to check performance
from sklearn.metrics import accuracy_score
# Out:
# 2023-04-26 08:50:21,860 https://nlp.informatik.hu-berlin.de/resources/models/sentiment-curated-distilbert/sentiment-en-mix-distillbert_4.pt not found in cache, downloading to /tmp/tmp96i2sf_8
# 100%|██████████| 253M/253M [00:12<00:00, 21.7MB/s]
# 2023-04-26 08:50:34,480 copying /tmp/tmp96i2sf_8 to cache at /root/.flair/models/sentiment-en-mix-distillbert_4.pt
# 2023-04-26 08:50:35,243 removing temp file /tmp/tmp96i2sf_8
# Downloading (…)okenizer_config.json:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
df = pd.read_csv('/content/drive/MyDrive/SentimentAnalysis/tweets_df_preprocessed.csv')

# %%
df['original_tweets'] = df['original_tweets'].str.strip()

# %%
df
# Out:
#        Unnamed: 0                       date            author_id  \
# 0               0  2023-03-31 00:54:56+00:00             80832189
# 1               1  2023-03-31 00:54:50+00:00           2479303121
# 2               2  2023-03-31 00:52:32+00:00  1526105788728475653
# 3               3  2023-03-31 00:52:09+00:00            438628988
# 4               4  2023-03-31 00:51:47+00:00  1492201362154831874
# ...           ...                        ...                  ...
# 22482       22482  2023-02-23 02:42:35+00:00  1492272489455620097
# 22483       22483  2023-02-23 02:29:15+00:00            452462161
# 22484       22484  2023-02-23 02:27:01+00:00  1519800752549421058
# 22485       22485  2023-02-23 02:25:21+00:00  1445411972388847622
# 22486       22486  2023-02-23 02:20:52+00:00             78746288
#
#                                                     text  \
# 0      ron desantis stated honor legal requirement ex...
# 1             abortion completely legal constitution . .
# 2          " forced pregnancy " legal term specifical...
# 3           americans know true , 80 % believe aborti...
# 4            democrats want legalize abortion scruples .
# ...                                                  ...
# 22482    abortion 9 months legal , past trimester ill...
# 22483      scotus rules decades ago privacy , fundame...
# 22484                yes . means obtain abortion legal .
# 22485     , injunction ( incorrectly ) placed trigger...
# 22486  blue america wants abortion legal mother takes...
#
#                                          original_tweets  \
# 0      Ron DeSantis just stated he would not honor a ...
# 1      Abortion is completely legal and in our consti...
# 2      "Forced pregnancy" is a legal term specificall...
# 3      Americans know this IS true, which is why 80% ...
# 4      Democrats that want to legalize abortion don’t...
# ...                                                  ...
# 22482  abortion up to 9 months shouldn’t be legal, an...
# 22483  SCOTUS also rules decades ago that privacy, be...
# 22484  Yes. And I will go to all means to obtain an a...
# 22485  Also, due to the injunction (incorrectly) plac...
# 22486  Blue America wants to make abortion legal up u...
#
#                                                   tokens  \
# 0      ['ron', 'desantis', 'stated', 'honor', 'legal'...
# 1      ['abortion', 'completely', 'legal', 'constitut...
# 2      ['"', 'forced', 'pregnancy', '"', 'legal', 'te...
# 3      ['americans', 'know', 'true', ',', '80', '%', ...
# 4      ['democrats', 'want', 'legalize', 'abortion', ...
# ...                                                  ...
# 22482  ['abortion', '9', 'months', 'legal', ',', 'pas...
# 22483  ['scotus', 'rules', 'decades', 'ago', 'privacy...
# 22484  ['yes', '.', 'means', 'obtain', 'abortion', 'l...
# 22485  [',', 'injunction', '(', 'incorrectly', ')', '...
# 22486  ['blue', 'america', 'wants', 'abortion', 'lega...
#
#                                           cleaned_tokens  \
# 0      ['ron', 'desantis', 'stated', 'honor', 'legal'...
# 1      ['abortion', 'completely', 'legal', 'constitut...
# 2      ['forced', 'pregnancy', 'legal', 'term', 'spec...
# 3      ['americans', 'know', 'true', '80', 'believe',...
# 4      ['democrats', 'want', 'legalize', 'abortion', ...
# ...                                                  ...
# 22482  ['abortion', 'months', 'legal', 'past', 'trime...
# 22483  ['scotus', 'rules', 'decades', 'ago', 'privacy...
# 22484    ['yes', 'means', 'obtain', 'abortion', 'legal']
# 22485  ['injunction', 'incorrectly', 'placed', 'trigg...
# 22486  ['blue', 'america', 'wants', 'abortion', 'lega...
#
#                                                    stems  \
# 0      ['ron', 'desanti', 'state', 'honor', 'legal', ...
# 1             ['abort', 'complet', 'legal', 'constitut']
# 2      ['forc', 'pregnanc', 'legal', 'term', 'specif'...
# 3      ['american', 'know', 'true', '80', 'believ', '...
# 4       ['democrat', 'want', 'legal', 'abort', 'scrupl']
# ...                                                  ...
# 22482  ['abort', 'month', 'legal', 'past', 'trimest',...
# 22483  ['scotu', 'rule', 'decad', 'ago', 'privaci', '...
# 22484         ['ye', 'mean', 'obtain', 'abort', 'legal']
# 22485  ['injunct', 'incorrectli', 'place', 'trigger',...
# 22486  ['blue', 'america', 'want', 'abort', 'legal', ...
#
#                                                    lemma
# 0      ['ron', 'desantis', 'state', 'honor', 'legal',...
# 1      ['abortion', 'completely', 'legal', 'constitut...
# 2      ['force', 'pregnancy', 'legal', 'term', 'speci...
# 3      ['americans', 'know', 'true', 'believe', 'abor...
# 4      ['democrats', 'want', 'legalize', 'abortion', ...
# ...                                                  ...
# 22482  ['abortion', 'month', 'legal', 'past', 'trimes...
# 22483  ['scotus', 'rule', 'decade', 'ago', 'privacy',...
# 22484     ['yes', 'mean', 'obtain', 'abortion', 'legal']
# 22485  ['injunction', 'incorrectly', 'place', 'trigge...
# 22486  ['blue', 'america', 'want', 'abortion', 'legal...
#
# [22487 rows x 9 columns]

# %%
# I want to use hugging_face model to predict sentiment for my tweets since clustering-labeling method is not the best one (only 34% precision score)
# then I want to compare results from clustering and hugging_face model

# %%
# Define pipeline

classifier = pipeline(task = 'zero-shot-classification',
                     model="facebook/bart-large-mnli",
                     device = 0)
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
import warnings
warnings.filterwarnings("ignore")

tweets = df['original_tweets'].to_list()
candidate_labels = ["positive", "negative"]

# Set the hyppothesis template
hypothesis_template = "The sentiment of this tweet is {}."

# Prediction results
zeroshot_prediction = classifier(tweets, candidate_labels, hypothesis_template=hypothesis_template)
zeroshot_prediction = pd.DataFrame(zeroshot_prediction)
zeroshot_prediction.head(10)
# Out:
#                                             sequence                labels  \
# 0  Ron DeSantis just stated he would not honor a ...  [negative, positive]
# 1  Abortion is completely legal and in our consti...  [negative, positive]
# 2  "Forced pregnancy" is a legal term specificall...  [negative, positive]
# 3  Americans know this IS true, which is why 80% ...  [positive, negative]
# 4  Democrats that want to legalize abortion don’t...  [negative, positive]
# 5  How Abortion Bans Are Impacting Pregnant Patie...  [negative, positive]
# 6  There are more people that want to make aborti...  [negative, positive]
# 7  How does an abortion ban become a forced gesta...  [negative, positive]
# 8  Pretty sure Republicans don't want any childre...  [negative, positive]
# 9  But those 1st 2 things he didn't do!\n\nPlease...  [negative, positive]
#
#                                        scores
# 0  [0.9887816309928894, 0.011218375526368618]
# 1    [0.5180108547210693, 0.4819890856742859]
# 2   [0.9548926949501038, 0.04510725289583206]
# 3   [0.8548560738563538, 0.14514391124248505]
# 4   [0.9443130493164062, 0.05568692460656166]
# 5   [0.7610181570053101, 0.23898188769817352]
# 6    [0.7828027009963989, 0.2171972692012787]
# 7   [0.9582416415214539, 0.04175836592912674]
# 8   [0.9405350685119629, 0.05946493148803711]
# 9   [0.9591174125671387, 0.04088260978460312]

# %%
zeroshot_prediction['zs_prediction'] = zeroshot_prediction['labels'].apply(lambda x: x[0])
zeroshot_prediction['zs_prediction'] = zeroshot_prediction['zs_prediction'].map({'positive': 0, 'negative': 1})
zeroshot_prediction['zs_predicted_score'] = zeroshot_prediction['scores'].apply(lambda x: x[0])

zeroshot_prediction.head(5)
# Out:
#                                             sequence                labels  \
# 0  Ron DeSantis just stated he would not honor a ...  [negative, positive]
# 1  Abortion is completely legal and in our consti...  [negative, positive]
# 2  "Forced pregnancy" is a legal term specificall...  [negative, positive]
# 3  Americans know this IS true, which is why 80% ...  [positive, negative]
# 4  Democrats that want to legalize abortion don’t...  [negative, positive]
#
#                                        scores  zs_prediction  \
# 0  [0.9887816309928894, 0.011218375526368618]              1
# 1    [0.5180108547210693, 0.4819890856742859]              1
# 2   [0.9548926949501038, 0.04510725289583206]              1
# 3   [0.8548560738563538, 0.14514391124248505]              0
# 4   [0.9443130493164062, 0.05568692460656166]              1
#
#    zs_predicted_score
# 0            0.988782
# 1            0.518011
# 2            0.954893
# 3            0.854856
# 4            0.944313

# %% [markdown]
#  # Here I also prepared my own-labeled 150 first tweets to compare results

# %%
zeroshot_prediction.to_excel('/content/drive/MyDrive/SentimentAnalysis/zero_shot_prediction.xlsx')

# %%
labeled_tweets = pd.read_excel('/content/drive/MyDrive/SentimentAnalysis/zero_shot_prediction_hands_labels.xlsx')

# %%
labeled_tweets.head(25)
# Out:
#                                              sequence  \
# 0   Ron DeSantis just stated he would not honor a ...
# 1   Abortion is completely legal and in our consti...
# 2   "Forced pregnancy" is a legal term specificall...
# 3   Americans know this IS true, which is why 80% ...
# 4   Democrats that want to legalize abortion don’t...
# 5   How Abortion Bans Are Impacting Pregnant Patie...
# 6   There are more people that want to make aborti...
# 7   How does an abortion ban become a forced gesta...
# 8   Pretty sure Republicans don't want any childre...
# 9   But those 1st 2 things he didn't do!\n\nPlease...
# 10  More than just women in Florida will suffer. N...
# 11  Typical Democrat hypocrisy. They only care abo...
# 12  Don't know about tracking Tweets, but, as you ...
# 13  More babies are killed every year from abortio...
# 14  Are you joking. Abortion is very legal in Cali...
# 15  “Religious extremists” meaning people who actu...
# 16  The argument that abortion is murder. It is no...
# 17  Conservatives are voting for legal Apartheid A...
# 18  6wk Abortion ban bitch if u miscarry you need ...
# 19  Don’t be distracted by all the other minutia r...
# 20  Don’t have cable\n\nClothes?! Books - school c...
# 21  Sure, but you can stretch the legal fight out ...
# 22  Quit killing babies, you are from Washington S...
# 23  “sAfE LeGaL aNd RaRe” is what they used to get...
# 24  Lawmakers call it "abortion trafficking" if so...
#
#                       labels                                      scores  \
# 0   ['negative', 'positive']  [0.9887816309928894, 0.011218375526368618]
# 1   ['negative', 'positive']    [0.5180108547210693, 0.4819890856742859]
# 2   ['negative', 'positive']   [0.9548926949501038, 0.04510725289583206]
# 3   ['positive', 'negative']   [0.8548560738563538, 0.14514391124248505]
# 4   ['negative', 'positive']   [0.9443130493164062, 0.05568692460656166]
# 5   ['negative', 'positive']   [0.7610181570053101, 0.23898188769817352]
# 6   ['negative', 'positive']    [0.7828027009963989, 0.2171972692012787]
# 7   ['negative', 'positive']   [0.9582416415214539, 0.04175836592912674]
# 8   ['negative', 'positive']   [0.9405350685119629, 0.05946493148803711]
# 9   ['negative', 'positive']   [0.9591174125671387, 0.04088260978460312]
# 10  ['negative', 'positive']   [0.984910786151886, 0.015089238993823528]
# 11  ['negative', 'positive']   [0.9801748991012573, 0.01982513628900051]
# 12  ['positive', 'negative']   [0.8366797566413879, 0.16332024335861206]
# 13  ['negative', 'positive']  [0.9809842109680176, 0.019015762954950333]
# 14  ['negative', 'positive']   [0.9332630634307861, 0.06673694401979446]
# 15  ['negative', 'positive']   [0.8820278644561768, 0.11797218024730682]
# 16  ['negative', 'positive']    [0.875042736530304, 0.12495725601911545]
# 17  ['negative', 'positive']    [0.956157922744751, 0.04384206607937813]
# 18  ['negative', 'positive']  [0.9911209344863892, 0.008879061788320541]
# 19  ['negative', 'positive']   [0.980057954788208, 0.019942007958889008]
# 20  ['negative', 'positive']  [0.9855411052703857, 0.014458877965807915]
# 21  ['negative', 'positive']    [0.8458923101425171, 0.1541077047586441]
# 22  ['negative', 'positive']   [0.8907517194747925, 0.10924824327230453]
# 23  ['negative', 'positive']   [0.974422812461853, 0.025577140972018242]
# 24  ['negative', 'positive']  [0.9852409958839417, 0.014759019948542118]
#
#     zs_prediction  zs_predicted_score  hand_labels
# 0               1            0.988782            1
# 1               1            0.518011            0
# 2               1            0.954893            1
# 3               0            0.854856            0
# 4               1            0.944313            1
# 5               1            0.761018            0
# 6               1            0.782803            1
# 7               1            0.958242            1
# 8               1            0.940535            1
# 9               1            0.959117            1
# 10              1            0.984911            0
# 11              1            0.980175            1
# 12              0            0.836680            1
# 13              1            0.980984            1
# 14              1            0.933263            0
# 15              1            0.882028            0
# 16              1            0.875043            0
# 17              1            0.956158            0
# 18              1            0.991121            0
# 19              1            0.980058            1
# 20              1            0.985541            1
# 21              1            0.845892            1
# 22              1            0.890752            1
# 23              1            0.974423            1
# 24              1            0.985241            1

# %%
from IPython.display import display
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score

# %%
predicted_classes = labeled_tweets.zs_prediction
y_test = labeled_tweets.hand_labels

conf_matrix = pd.DataFrame(confusion_matrix(labeled_tweets.hand_labels, labeled_tweets.zs_prediction))
print('Confusion Matrix')
display(conf_matrix)

test_scores = accuracy_score(y_test,predicted_classes), precision_score(y_test, predicted_classes), recall_score(y_test, predicted_classes), f1_score(y_test, predicted_classes)

print('\n \n Scores')
scores = pd.DataFrame(data=[test_scores])
scores.columns = ['accuracy', 'precision', 'recall', 'f1']
scores = scores.T
scores.columns = ['scores']
display(scores)
# Out:
# Confusion Matrix
#     0   1
# 0  26  74
# 1   5  46
#
#  Scores
#              scores
# accuracy   0.476821
# precision  0.383333
# recall     0.901961
# f1         0.538012

# %% [markdown]
#  # 47% accuracy score. It still not good, but it's better than clustering results so I will use zero-shot method to label my tweets

# %%
zeroshot_prediction = zeroshot_prediction.rename(columns={'sequence': 'original_tweets'})
zeroshot_prediction
# Out:
#                                          original_tweets  \
# 0      Ron DeSantis just stated he would not honor a ...
# 1      Abortion is completely legal and in our consti...
# 2      "Forced pregnancy" is a legal term specificall...
# 3      Americans know this IS true, which is why 80% ...
# 4      Democrats that want to legalize abortion don’t...
# ...                                                  ...
# 22482  abortion up to 9 months shouldn’t be legal, an...
# 22483  SCOTUS also rules decades ago that privacy, be...
# 22484  Yes. And I will go to all means to obtain an a...
# 22485  Also, due to the injunction (incorrectly) plac...
# 22486  Blue America wants to make abortion legal up u...
#
#                      labels                                      scores  \
# 0      [negative, positive]  [0.9887816309928894, 0.011218375526368618]
# 1      [negative, positive]    [0.5180108547210693, 0.4819890856742859]
# 2      [negative, positive]   [0.9548926949501038, 0.04510725289583206]
# 3      [positive, negative]   [0.8548560738563538, 0.14514391124248505]
# 4      [negative, positive]   [0.9443130493164062, 0.05568692460656166]
# ...                     ...                                         ...
# 22482  [negative, positive]  [0.9908162355422974, 0.009183789603412151]
# 22483  [negative, positive]   [0.9144995808601379, 0.08550041913986206]
# 22484  [negative, positive]   [0.9525007009506226, 0.04749932140111923]
# 22485  [negative, positive]   [0.9203109741210938, 0.07968904823064804]
# 22486  [negative, positive]  [0.9534608721733093, 0.046539075672626495]
#
#        zs_prediction  zs_predicted_score
# 0                  1            0.988782
# 1                  1            0.518011
# 2                  1            0.954893
# 3                  0            0.854856
# 4                  1            0.944313
# ...              ...                 ...
# 22482              1            0.990816
# 22483              1            0.914500
# 22484              1            0.952501
# 22485              1            0.920311
# 22486              1            0.953461
#
# [22487 rows x 5 columns]

# %%
df = df.merge(zeroshot_prediction[['original_tweets', 'zs_prediction']], on='original_tweets', how='left')
df
# Out:
#        Unnamed: 0                       date            author_id  \
# 0               0  2023-03-31 00:54:56+00:00             80832189
# 1               1  2023-03-31 00:54:50+00:00           2479303121
# 2               2  2023-03-31 00:52:32+00:00  1526105788728475653
# 3               3  2023-03-31 00:52:09+00:00            438628988
# 4               4  2023-03-31 00:51:47+00:00  1492201362154831874
# ...           ...                        ...                  ...
# 23826       22482  2023-02-23 02:42:35+00:00  1492272489455620097
# 23827       22483  2023-02-23 02:29:15+00:00            452462161
# 23828       22484  2023-02-23 02:27:01+00:00  1519800752549421058
# 23829       22485  2023-02-23 02:25:21+00:00  1445411972388847622
# 23830       22486  2023-02-23 02:20:52+00:00             78746288
#
#                                                     text  \
# 0      ron desantis stated honor legal requirement ex...
# 1             abortion completely legal constitution . .
# 2          " forced pregnancy " legal term specifical...
# 3           americans know true , 80 % believe aborti...
# 4            democrats want legalize abortion scruples .
# ...                                                  ...
# 23826    abortion 9 months legal , past trimester ill...
# 23827      scotus rules decades ago privacy , fundame...
# 23828                yes . means obtain abortion legal .
# 23829     , injunction ( incorrectly ) placed trigger...
# 23830  blue america wants abortion legal mother takes...
#
#                                          original_tweets  \
# 0      Ron DeSantis just stated he would not honor a ...
# 1      Abortion is completely legal and in our consti...
# 2      "Forced pregnancy" is a legal term specificall...
# 3      Americans know this IS true, which is why 80% ...
# 4      Democrats that want to legalize abortion don’t...
# ...                                                  ...
# 23826  abortion up to 9 months shouldn’t be legal, an...
# 23827  SCOTUS also rules decades ago that privacy, be...
# 23828  Yes. And I will go to all means to obtain an a...
# 23829  Also, due to the injunction (incorrectly) plac...
# 23830  Blue America wants to make abortion legal up u...
#
#                                                   tokens  \
# 0      ['ron', 'desantis', 'stated', 'honor', 'legal'...
# 1      ['abortion', 'completely', 'legal', 'constitut...
# 2      ['"', 'forced', 'pregnancy', '"', 'legal', 'te...
# 3      ['americans', 'know', 'true', ',', '80', '%', ...
# 4      ['democrats', 'want', 'legalize', 'abortion', ...
# ...                                                  ...
# 23826  ['abortion', '9', 'months', 'legal', ',', 'pas...
# 23827  ['scotus', 'rules', 'decades', 'ago', 'privacy...
# 23828  ['yes', '.', 'means', 'obtain', 'abortion', 'l...
# 23829  [',', 'injunction', '(', 'incorrectly', ')', '...
# 23830  ['blue', 'america', 'wants', 'abortion', 'lega...
#
#                                           cleaned_tokens  \
# 0      ['ron', 'desantis', 'stated', 'honor', 'legal'...
# 1      ['abortion', 'completely', 'legal', 'constitut...
# 2      ['forced', 'pregnancy', 'legal', 'term', 'spec...
# 3      ['americans', 'know', 'true', '80', 'believe',...
# 4      ['democrats', 'want', 'legalize', 'abortion', ...
# ...                                                  ...
# 23826  ['abortion', 'months', 'legal', 'past', 'trime...
# 23827  ['scotus', 'rules', 'decades', 'ago', 'privacy...
# 23828    ['yes', 'means', 'obtain', 'abortion', 'legal']
# 23829  ['injunction', 'incorrectly', 'placed', 'trigg...
# 23830  ['blue', 'america', 'wants', 'abortion', 'lega...
#
#                                                    stems  \
# 0      ['ron', 'desanti', 'state', 'honor', 'legal', ...
# 1             ['abort', 'complet', 'legal', 'constitut']
# 2      ['forc', 'pregnanc', 'legal', 'term', 'specif'...
# 3      ['american', 'know', 'true', '80', 'believ', '...
# 4       ['democrat', 'want', 'legal', 'abort', 'scrupl']
# ...                                                  ...
# 23826  ['abort', 'month', 'legal', 'past', 'trimest',...
# 23827  ['scotu', 'rule', 'decad', 'ago', 'privaci', '...
# 23828         ['ye', 'mean', 'obtain', 'abort', 'legal']
# 23829  ['injunct', 'incorrectli', 'place', 'trigger',...
# 23830  ['blue', 'america', 'want', 'abort', 'legal', ...
#
#                                                    lemma  zs_prediction
# 0      ['ron', 'desantis', 'state', 'honor', 'legal',...              1
# 1      ['abortion', 'completely', 'legal', 'constitut...              1
# 2      ['force', 'pregnancy', 'legal', 'term', 'speci...              1
# 3      ['americans', 'know', 'true', 'believe', 'abor...              0
# 4      ['democrats', 'want', 'legalize', 'abortion', ...              1
# ...                                                  ...            ...
# 23826  ['abortion', 'month', 'legal', 'past', 'trimes...              1
# 23827  ['scotus', 'rule', 'decade', 'ago', 'privacy',...              1
# 23828     ['yes', 'mean', 'obtain', 'abortion', 'legal']              1
# 23829  ['injunction', 'incorrectly', 'place', 'trigge...              1
# 23830  ['blue', 'america', 'want', 'abortion', 'legal...              1
#
# [23831 rows x 10 columns]

# %%
df.to_csv('/content/drive/MyDrive/SentimentAnalysis/tweets_df_cleaned_labeled.csv')
